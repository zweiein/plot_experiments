# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os

def save(path, ext='png', close=True, verbose=True):
    """Save a figure from pyplot.
    Parameters
    ----------
    path : string
        The path (and filename, without the extension) to save the
        figure to.
    ext : string (default='png')
        The file extension. This must be supported by the active
        matplotlib backend (see matplotlib.backends module).  Most
        backends support 'png', 'pdf', 'ps', 'eps', and 'svg'.
    close : boolean (default=True)
        Whether to close the figure after saving.  If you want to save
        the figure multiple times (e.g., to multiple formats), you
        should NOT close it in between saves or you will have to
        re-plot it.
    verbose : boolean (default=True)
        Whether to print information about when and where the image
        has been saved.
    """
    
    # Extract the directory and filename from the given path
    directory = os.path.split(path)[0]
    filename = "%s.%s" % (os.path.split(path)[1], ext)
    if directory == '':
        directory = '.'

    # If the directory does not exist, create it
    if not os.path.exists(directory):
        os.makedirs(directory)

    # The final path to save to
    savepath = os.path.join(directory, filename)

    if verbose:
        print("Saving figure to '%s'..." % savepath),

    # Actually save the figure
    plt.savefig(savepath)
    
    # Close it
    if close:
        plt.close()

    if verbose:
        print("Done")

# %%
fp = open('all_dt.log', 'r')
split_list = fp.read().split('\n')

f_CNNdt_LSTMdt_DNNdt = split_list[4].split()
t_CNNdt_LSTMdt_DNNdt = split_list[5].split()

del f_CNNdt_LSTMdt_DNNdt[0]
del t_CNNdt_LSTMdt_DNNdt[0]

#-----------------------
fp = open('CNN+LSTM.log', 'r')
split_list = fp.read().split('\n')

f_CNN_LSTM = split_list[4].split()
t_CNN_LSTM = split_list[5].split()

del f_CNN_LSTM[0]
del t_CNN_LSTM[0]

#-----------------------
fp = open('CNNdt+LSTMdt.log', 'r')
split_list = fp.read().split('\n')

f_CNNdt_LSTMdt = split_list[4].split()
t_CNNdt_LSTMdt = split_list[5].split()

del f_CNNdt_LSTMdt[0]
del t_CNNdt_LSTMdt[0]

#-----------------------
fp = open('DNN+CNN.log', 'r')
split_list = fp.read().split('\n')

f_DNN_CNN = split_list[4].split()
t_DNN_CNN = split_list[5].split()

del f_DNN_CNN[0]
del t_DNN_CNN[0]

#-----------------------
fp = open('DNNdt+CNNdt.log', 'r')
split_list = fp.read().split('\n')

f_DNNdt_CNNdt = split_list[4].split()
t_DNNdt_CNNdt = split_list[5].split()

del f_DNNdt_CNNdt[0]
del t_DNNdt_CNNdt[0]

#-----------------------
fp = open('DNN.log', 'r')
split_list = fp.read().split('\n')

f_DNN = split_list[4].split()
t_DNN = split_list[5].split()

del f_DNN[0]
del t_DNN[0]

#-----------------------
fp = open('CNN.log', 'r')
split_list = fp.read().split('\n')

f_CNN = split_list[4].split()
t_CNN = split_list[5].split()

del f_CNN[0]
del t_CNN[0]

#-----------------------
fp = open('LSTM.log', 'r')
split_list = fp.read().split('\n')

f_LSTM = split_list[4].split()
t_LSTM = split_list[5].split()

del f_LSTM[0]
del t_LSTM[0]
#plt.plot(map(float, FAR), map(float, TAR))
#plt.grid(b=True, which='minor', color='r', linestyle='--')


# Make some fake data.
#a = b = np.arange(0, 3, .02)
#c = np.exp(a)
#d = c[::-1]

# Create plots with pre-defined labels.
plt.plot(f_DNN, t_DNN,'g:', label='DNN')
plt.plot(f_CNN, t_CNN,'b:', label='CNN')
plt.plot(f_LSTM, t_LSTM,'r:', label='LSTM')
plt.plot(f_CNNdt_LSTMdt_DNNdt, t_CNNdt_LSTMdt_DNNdt,'k-', label='CNNdt+LSTMdt+DNNdt')
plt.plot(f_CNN_LSTM, t_CNN_LSTM, 'r--', label='CNN+LSTM')
plt.plot(f_CNNdt_LSTMdt, t_CNNdt_LSTMdt, 'b--', label='CNNdt+LSTMdt')
plt.plot(f_DNN_CNN, t_DNN_CNN, 'g--', label='DNN+CNN')
plt.plot(f_DNNdt_CNNdt, t_DNNdt_CNNdt, 'm--', label='DNNdt+CNNdt')
#plt.plot(FAR, 'k:', label='FAR')
#plt.plot(TAR, 'k', label='Total message length')

legend = plt.legend(loc='lower right', shadow=True, fontsize='medium')

# Put a nicer background color on the legend.
legend.get_frame().set_facecolor('#FFFFFF')

plt.xlabel("False positive rate(FPR)")
plt.ylabel("True positive rate(TPR)")
#plt.grid(True)

plt.xticks(np.arange(0, 1.1, 0.1))
plt.yticks(np.arange(0, 1.1, 0.1))
#save("result", ext="png", close=False, verbose=True)
plt.savefig("1.png", format='png', dpi=300)
plt.show()
